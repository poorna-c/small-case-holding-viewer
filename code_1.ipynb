# %%
import pandas as pd

# Load excel
df = pd.read_excel("portfolio.xlsx")

# Forward fill Date Range column
df['Date Range'] = df['Date Range'].ffill()

# Extract start date
df['Start Date'] = df['Date Range'].str.split(" to ").str[0]
df['Start Date'] = pd.to_datetime(df['Start Date'])

# Sort
df = df.sort_values(['Constituents', 'Start Date'])

# %%
df.head(10)
# Out:
#                     Date Range               Constituents  Weightage  \
# 1311  2021-11-08 to 2021-11-14                    ACC Ltd       0.08
# 1321  2021-11-15 to 2021-11-21                    ACC Ltd       0.08
# 1331  2021-11-22 to 2021-11-28                    ACC Ltd       0.08
# 2233  2023-10-16 to 2023-10-18       APL Apollo Tubes Ltd       0.09
# 81    2019-05-27 to 2019-06-02  AU Small Finance Bank Ltd       0.10
# 91    2019-06-03 to 2019-06-09  AU Small Finance Bank Ltd       0.10
# 100   2019-06-10 to 2019-06-16  AU Small Finance Bank Ltd       0.10
# 111   2019-06-17 to 2019-06-23  AU Small Finance Bank Ltd       0.10
# 120   2019-06-24 to 2019-06-30  AU Small Finance Bank Ltd       0.11
# 131   2019-07-01 to 2019-07-07  AU Small Finance Bank Ltd       0.11
#
#      Start Date
# 1311 2021-11-08
# 1321 2021-11-15
# 1331 2021-11-22
# 2233 2023-10-16
# 81   2019-05-27
# 91   2019-06-03
# 100  2019-06-10
# 111  2019-06-17
# 120  2019-06-24
# 131  2019-07-01

# %%
holding_periods = []

for stock, group in df.groupby('Constituents'):
    group = group.sort_values('Start Date')
    dates = group['Start Date'].unique()

    entry = dates[0]
    prev_date = dates[0]

    for current_date in dates[1:]:
        if (current_date - prev_date).days > 7:
            # Exit detected
            holding_periods.append({
                "Stock": stock,
                "Entry": entry,
                "Exit": prev_date
            })
            entry = current_date

        prev_date = current_date

    # Final exit
    holding_periods.append({
        "Stock": stock,
        "Entry": entry,
        "Exit": prev_date
    })

holding_df = pd.DataFrame(holding_periods)

holding_df['Holding Days'] = (holding_df['Exit'] - holding_df['Entry']).dt.days
holding_df['Holding Weeks'] = holding_df['Holding Days'] / 7

# %%
holding_df.head(20)
# Out:
#                                         Stock      Entry       Exit  \
# 0                                     ACC Ltd 2021-11-08 2021-11-22
# 1                        APL Apollo Tubes Ltd 2023-10-16 2023-10-16
# 2                   AU Small Finance Bank Ltd 2019-05-27 2019-07-08
# 3                             Aarti Drugs Ltd 2020-05-18 2020-05-18
# 4                             Aarti Drugs Ltd 2020-05-26 2020-10-19
# 5                       Adani Enterprises Ltd 2022-07-11 2022-08-08
# 6                       Adani Enterprises Ltd 2022-08-16 2022-10-03
# 7                      Adani Green Energy Ltd 2020-05-18 2020-05-18
# 8                      Adani Green Energy Ltd 2020-05-26 2020-11-09
# 9                      Adani Green Energy Ltd 2020-11-17 2020-11-23
# 10                     Adani Green Energy Ltd 2020-12-01 2020-12-07
# 11  Adani Ports and Special Economic Zone Ltd 2020-12-07 2021-03-22
# 12  Adani Ports and Special Economic Zone Ltd 2021-03-30 2021-06-14
# 13                        Adani Total Gas Ltd 2021-02-01 2021-03-22
# 14                        Adani Total Gas Ltd 2021-03-30 2021-06-14
# 15                     Adani Transmission Ltd 2022-07-18 2022-08-08
# 16                     Adani Transmission Ltd 2022-08-16 2022-10-17
# 17                     Adani Transmission Ltd 2022-10-25 2022-11-21
# 18                Alembic Pharmaceuticals Ltd 2020-04-13 2020-05-18
# 19                Alembic Pharmaceuticals Ltd 2020-05-26 2020-08-31
#
#     Holding Days  Holding Weeks
# 0             14       2.000000
# 1              0       0.000000
# 2             42       6.000000
# 3              0       0.000000
# 4            146      20.857143
# 5             28       4.000000
# 6             48       6.857143
# 7              0       0.000000
# 8            167      23.857143
# 9              6       0.857143
# 10             6       0.857143
# 11           105      15.000000
# 12            76      10.857143
# 13            49       7.000000
# 14            76      10.857143
# 15            21       3.000000
# 16            62       8.857143
# 17            27       3.857143
# 18            35       5.000000
# 19            97      13.857143

# %%
import plotly.express as px

fig = px.timeline(
    holding_df,
    x_start="Entry",
    x_end="Exit",
    y="Stock",
    color="Stock"
)

fig.update_yaxes(autorange="reversed")
fig.show()
